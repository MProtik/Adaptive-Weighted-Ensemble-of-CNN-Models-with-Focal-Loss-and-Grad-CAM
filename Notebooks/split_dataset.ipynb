# %%
import os
import shutil
import random
from tqdm import tqdm

# %%
src_dir = "/content/drive/MyDrive/Research paper on cnn and ensemble learning/Dataset/Folder according to classes"
output_dir = "/content/drive/MyDrive/Research paper on cnn and ensemble learning/Dataset/Splitted_dataset"

# %%
classes = []

for cls in os.listdir(src_dir):
  classes.append(cls)

# %%
type(classes[0])
# Out:
# str

# %%
random.seed(42)

# %%
for cls in classes:
  class_dir = os.path.join(src_dir, cls)
  images = os.listdir(class_dir)
  random.shuffle(images)

  total_number = len(images)
  train_number = int(total_number * 0.8)
  val_number = int(total_number * 0.1)

  train_images = images[:train_number]
  val_images =  images[train_number: train_number + val_number]
  test_images = images[train_number + val_number:]

  for split_name, split_images in zip(["train", "val", "test"], [train_images, val_images, test_images]):
    split_dir = os.path.join(output_dir, split_name, cls)
    os.makedirs(split_dir)
    for img in tqdm(split_images):
      src = os.path.join(class_dir, img)
      dst = os.path.join(split_dir, img)
      shutil.copy2(src, dst)

print("\n✅ Dataset successfully split into train/val/test folders!")
print(f"Output directory: {os.path.abspath(output_dir)}")
# Out:
# 100%|██████████| 879/879 [01:45<00:00,  8.36it/s]
# 100%|██████████| 109/109 [00:09<00:00, 11.99it/s]
# 100%|██████████| 111/111 [00:08<00:00, 13.20it/s]
# 100%|██████████| 890/890 [01:06<00:00, 13.43it/s]
# 100%|██████████| 111/111 [00:04<00:00, 25.75it/s]
# 100%|██████████| 112/112 [00:06<00:00, 16.65it/s]
# 100%|██████████| 261/261 [00:10<00:00, 23.99it/s]
# 100%|██████████| 32/32 [00:00<00:00, 56.16it/s]
# 100%|██████████| 34/34 [00:00<00:00, 60.77it/s]
# 100%|██████████| 92/92 [00:04<00:00, 20.00it/s]
# 100%|██████████| 11/11 [00:00<00:00, 52.78it/s]
# 100%|██████████| 12/12 [00:00<00:00, 24.26it/s]
# 100%|██████████| 411/411 [00:22<00:00, 18.05it/s]
# 100%|██████████| 51/51 [00:02<00:00, 21.10it/s]
# 100%|██████████| 52/52 [00:03<00:00, 16.17it/s]
# 100%|██████████| 5364/5364 [13:03<00:00,  6.85it/s]
# 100%|██████████| 670/670 [00:26<00:00, 25.66it/s]
# 100%|██████████| 671/671 [00:24<00:00, 27.45it/s]
# 100%|██████████| 113/113 [00:07<00:00, 15.74it/s]
# 100%|██████████| 14/14 [00:01<00:00, 10.36it/s]
# 100%|██████████| 15/15 [00:00<00:00, 53.74it/s]
# ✅ Dataset successfully split into train/val/test folders!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3872073247.py in <cell line: 0>()
#      21
#      22 print("\n✅ Dataset successfully split into train/val/test folders!")
# ---> 23 print(f"Train ratio: {train_ratio}, Val ratio: {val_ratio}, Test ratio: {test_ratio}")
#      24 print(f"Output directory: {os.path.abspath(output_dir)}")
#
# NameError: name 'train_ratio' is not defined

# %%
print(f"Output directory: {os.path.abspath(output_dir)}")
# Out:
# Output directory: /content/drive/MyDrive/Research paper on cnn and ensemble learning/Dataset/Splitted_dataset
